# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df =  pd.read_csv('processedWithHeader.cleveland.data', sep=",")
print(df)
df.shape
df.columns
df.nunique()
df.describe()

sns.set(style="white") 
plt.rcParams['figure.figsize'] = (15, 10) 
sns.heatmap(data.corr(), annot = True, linewidths=.5, cmap="Blues")
plt.title('Corelation Between Variables', fontsize = 30)
plt.show()

sns.pairplot(data)
plt.show()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  goal
# 0      3.0  0.0  6.0     0
# ...

# %%
df=pd.read_csv('processedWithHeader.cleveland.data', sep=",")
for x in df.columns:
    df = df[~df[x].astype(str).str.startswith('?')]
    df[x] = df[x].astype(float)
df.reset_index(drop=True)
print(df)
df.shape
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  goal
# ...

# %%
pd.set_option('display.max_rows', data.shape[0]+1)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 10   57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ...

# %%
for x in df.columns:
    df = df[~df[x].astype(str).str.startswith('?')]
    df[x] = df[x].astype(float)
df=df.reset_index(drop=True)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 10   57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ...

# %%
#KNN

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
  

  
# Create feature and target arrays
X = df.drop("goal",axis=1)
y = df.loc[:,"goal"]

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(
             X, y, test_size = 0.1, random_state=42)
  
knn = KNeighborsClassifier(n_neighbors=13)
  
knn.fit(X_train, y_train)
  
# Calculate the accuracy of the model
print(knn.score(X_test, y_test))
# Out:
# 0.6666666666666666

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
 
# import the iris dataset
X = df.drop("goal",axis=1)
y = df.loc[:,"goal"]

 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1)
 
# GAUSSIAN NAIVE BAYES
gnb = GaussianNB()
# train the model
gnb.fit(X_train, y_train)
# make predictions
gnb_pred = gnb.predict(X_test)
# print the accuracy
print("Accuracy of Gaussian Naive Bayes: ", accuracy_score(y_test, gnb_pred))
 
# DECISION TREE CLASSIFIER
dt = DecisionTreeClassifier(random_state=0)
# train the model
dt.fit(X_train, y_train)
# make predictions
dt_pred = dt.predict(X_test)
# print the accuracy
print("Accuracy of Decision Tree Classifier: ", accuracy_score(y_test, dt_pred))
 
# SUPPORT VECTOR MACHINE
svm_clf = svm.SVC(kernel='linear')  # Linear Kernel
# train the model
svm_clf.fit(X_train, y_train)
# make predictions
svm_clf_pred = svm_clf.predict(X_test)
# print the accuracy
print("Accuracy of Support Vector Machine: ",
      accuracy_score(y_test, svm_clf_pred))
# Out:
# Accuracy of Gaussian Naive Bayes:  0.5333333333333333
# Accuracy of Decision Tree Classifier:  0.5166666666666667
# Accuracy of Support Vector Machine:  0.5

# %%
bdf=df.copy()
updated=bdf["goal"]>=1.0
bdf.loc[updated,"goal"]=1
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 10   57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
 
# import the iris dataset
X = bdf.drop("goal",axis=1)
y =bdf.loc[:,"goal"]

 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1)
 
# GAUSSIAN NAIVE BAYES
gnb = GaussianNB()
# train the model
gnb.fit(X_train, y_train)
# make predictions
gnb_pred = gnb.predict(X_test)
# print the accuracy
print("Accuracy of Gaussian Naive Bayes: ", accuracy_score(y_test, gnb_pred))
 
# DECISION TREE CLASSIFIER
dt = DecisionTreeClassifier(random_state=0)
# train the model
dt.fit(X_train, y_train)
# make predictions
dt_pred = dt.predict(X_test)
# print the accuracy
print("Accuracy of Decision Tree Classifier: ", accuracy_score(y_test, dt_pred))
 
# SUPPORT VECTOR MACHINE
svm_clf = svm.SVC(kernel='linear')  # Linear Kernel
# train the model
svm_clf.fit(X_train, y_train)
# make predictions
svm_clf_pred = svm_clf.predict(X_test)
# print the accuracy
print("Accuracy of Support Vector Machine: ",
      accuracy_score(y_test, svm_clf_pred))
# Out:
# Accuracy of Gaussian Naive Bayes:  0.8555555555555555
# Accuracy of Decision Tree Classifier:  0.7111111111111111
# Accuracy of Support Vector Machine:  0.8333333333333334

# %%
# We check if the feature columns are similarly distributed by means of the boxplot for some of the columns. We realize that they are NOT
df.boxplot(column=['age','sex','trestbps','chol', 'fbs', 'restecg'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d111e26c1726> in <module>
#       1 # We check if the feature columns are similarly distributed by means of the boxplot for some of the columns. We realize that they are NOT.
# ----> 2 data_cleaned.boxplot(column=['age','sex','trestbps','chol', 'fbs', 'restecg'])
#
# NameError: name 'data_cleaned' is not defined

# %%
# We prepare the data for scaling
df_new = df.iloc[:,:-1]
df_new.head()

# %%
# scaling
from sklearn.preprocessing import StandardScaler
variables = list(df_new.columns)
x = df_new.loc[:, variables].values
x = StandardScaler().fit_transform(x)
x = pd.DataFrame(x)
x.head()

# %%
# We check again if the feature columns are similarly distributed by means of the boxplot for some of the columns. We realize that they are.
x.boxplot(column=[0,1,2,3,4,5,6])

# %%
# We are aware of the imbalance of our data, the Non-ASD are dominating over the ASD genes.
import seaborn as sns
sns.countplot(x = 'num', data=df)

# %%
# aiming to balance the data, we use SMOTE to include for minority classes more instances
from pandas import read_csv
from imblearn.over_sampling import SMOTE
from collections import Counter
from matplotlib import pyplot

oversample = SMOTE()
y = df['num']
x, Y_labels = oversample.fit_resample(x, y)
# summarize distribution
counter = Counter(Y_labels)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.bar(counter.keys(), counter.values())
pyplot.show()

# %%
x.head()

# %%
# first classifier, SVM
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, Y_labels)
svclassifier = SVC(kernel='rbf', probability=True)
#svclassifier = svm.SVC(kernel='rbf', gamma=0.001, C=100,probability=True)
svclassifier.fit(X_train, y_train)
y_predict = svclassifier.predict(X_test)
y_pred = svclassifier.predict(X_test)

y_pred = svclassifier.predict(X_train)
y_probs= svclassifier.predict_proba(X_train)
y_preds = y_probs[:,1]
probs= svclassifier.predict_proba(X_test)
preds = probs[:,1]
confusionMatrix = confusion_matrix(y_test,y_pred)
confusionMatrix

# %%
sns.heatmap(confusionMatrix)

# %%
# In order to check for accuracy, we need to transform the continuous probability score data into binary one after setting 
# a threshhold.
y_pred = [1 if n>0.8 else 0 for n in preds]
print(preds[:10])
y_pred[:10]
# train data
y_pred_tr = [1 if n>0.8 else 0 for n in y_preds]
print(y_preds[:10])
y_pred_tr[:10]

# %%
# We import the tools for the accuracy score
from sklearn.metrics import accuracy_score
print("score on test: " + str(accuracy_score(y_test, y_pred)))
print("score on train: "+ str(accuracy_score(y_train, y_pred_tr)))
#accuracy_score(y_true, y_pred, normalize=False)
#preds[:5]

# %%
# We try as second classifier the logistic regression
from sklearn.linear_model import LogisticRegression
lr = logModel = LogisticRegression() 
lr = logModel.fit(X_train,y_train) #fitting the model
predictions = logModel.predict(X_test) #predicting on test set
predict_proba = logModel.predict_proba(X_test) #predicting on test set, returns probabilities as float numbers between 0 and 1
print("train shape: " + str(X_train.shape))
print("score on test: " + str(lr.score(X_test, y_test)))
print("score on train: "+ str(lr.score(X_train, y_train)))

# %%
#Importing confusion matrix from the sklearn library after the fine tuning
from sklearn.metrics import confusion_matrix

# build the confusion matrix
cnf_matrix_LR = confusion_matrix(y_test, predictions)

#printing the confusion matrix
print(cnf_matrix_LR)

# %%
# confusion matrix of the logistic regression classifier
sns.heatmap(cnf_matrix_LR)

# %%
# We use as third classifier random forests
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 0, max_depth=6)
classifier3.fit(X_train,y_train)
Y_Pred_proba = classifier3.predict_proba(X_test)
#predictions_rfc = classifier2.predict(X_test)
Y_Pred = classifier3.predict(X_test)
Y_Pred_tr = classifier3.predict(X_train)
print("score on test: " + str(accuracy_score(y_test, Y_Pred)))
print("score on train: "+ str(accuracy_score(y_train, Y_Pred_tr)))

# %%
# Now we will train the classifiers such that the multi-label problem is converted into a binary one
import copy
Y_labels.head()
Y_labels_backup = Y_labels.copy()
y_list =[0 if i==0 else 1 for i in Y_labels]
Y_labels = pd.Series(y_list)

# %%
# We will train all the classifiers again
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, Y_labels)
svclassifier = SVC(kernel='rbf', probability=True)
#svclassifier = svm.SVC(kernel='rbf', gamma=0.001, C=100,probability=True)
svclassifier.fit(X_train, y_train)
y_predict = svclassifier.predict(X_test)
y_pred = svclassifier.predict(X_test)
probs= svclassifier.predict_proba(X_test)
preds = probs[:,1]
confusionMatrix = confusion_matrix(y_test,y_pred)
confusionMatrix

# %%
Y_labels.unique()

# %%
sns.heatmap(confusionMatrix)

# %%
# We try as second classifier the logistic regression
from sklearn.linear_model import LogisticRegression
lr = logModel = LogisticRegression() 
lr = logModel.fit(X_train,y_train) #fitting the model
predictions = logModel.predict(X_test) #predicting on test set
predict_proba = logModel.predict_proba(X_test) #predicting on test set, returns probabilities as float numbers between 0 and 1
print("train shape: " + str(X_train.shape))
print("score on test: " + str(lr.score(X_test, y_test)))
print("score on train: "+ str(lr.score(X_train, y_train)))

# %%
#Importing confusion matrix from the sklearn library after the fine tuning
from sklearn.metrics import confusion_matrix

# build the confusion matrix
cnf_matrix_LR = confusion_matrix(y_test, predictions)

#printing the confusion matrix
print(cnf_matrix_LR)

# %%
# confusion matrix of the logistic regression classifier
sns.heatmap(cnf_matrix_LR)

# %%
# We use as third classifier random forests
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 0, max_depth=6)
classifier3.fit(X_train,y_train)
Y_Pred_proba = classifier3.predict_proba(X_test)
#predictions_rfc = classifier2.predict(X_test)
Y_Pred = classifier3.predict(X_test)
Y_Pred_tr = classifier3.predict(X_train)

# %%
# build the confusion matrix
cnf_matrix_RF = confusion_matrix(y_test, Y_Pred)

#printing the confusion matrix
print(cnf_matrix_RF)

# %%
# As measure of how well the classifers are running in terms of the precision power, we include the ROC curves
# We want to plot ROC curves related to different classifiers on the same plot
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

plt.figure()

# Add the models to the list that you want to view on the ROC plot
models = [
{
    'label': 'Logistic Regression',
    #'model': LogisticRegression(),
    'y_pred': predict_proba[:,1]
},
{
    'label': 'SVM',
    #'model': SVM(),
    'y_pred': preds
},
{
     'label': 'RandomForestClassifier',
     #'model':  RandomForestClassifier(),
     'y_pred': Y_Pred_proba[:,1]
},
]

# Below for loop iterates through your models list
for m in models:
    #model = m['model'] # select the model
    #model.fit(x_train, y_train) # train the model
    #y_pred=model.predict(x_test) # predict the test data
    print('LABEL:', m['label'])
    y_pred = m['y_pred']
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)

   # fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label= 'ovr')

# Calculate Area under the curve to display on the plot
    auc = metrics.roc_auc_score(y_test, y_pred)
# Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['label'], auc))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
